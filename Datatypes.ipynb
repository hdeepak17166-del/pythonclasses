# %%
#data type
a=10
b="10"
c="word"
d=None
e=True
f=False
g=10.5
print(type(c),type(a))    #type function ---to find the datatype pf the variable 
print(id(b)) #id is the function used to find the loction

# %%
A=10
B=12
C=A%B
print("The reminder is:",C) # the arthemetic operatora *,%,/,+ etc
# Out:
# The reminder is: 10

# %%
a=10
b=10
print(a==b) #relation operators like !=,<=, >=, <, >
# Out:
# True

# %%
#assinment operatora 
j=10
j+=10
print(j)
# Out:
# 20

# %%
#logical operators 
a=True
b=False
print(a and b)
print(a or b)
print(not a)
# Out:
# False
# True
# False

# %% [markdown]
# AND
# T AND T= T
# T AND F= F
# F AND T= F
# F AND F= F
#
# OR
# T OR T= T
# T OR F= T
# F OR T= T
# F OR F= F
#
# NOT
# NOT T= F
# NOT F= T

# %%
#input function
a=input("enter your name")
print("hello", a)
print(type(a))
# Out:
# hello h deepak
# <class 'str'>

# %%
#Type casting --- chaning the datatype of another datatype
a=int(input("enter a value for a"))
b=int(input("enter a value for b") )
sum=a+b
print("The sum of the values entered is ",sum)
# Out:
# The sum of the values entered is  30

# %%
side=float(input("Enter the side lenght of the square"))
area=side*side
print("Area of the square is:", area)
# Out:
# Area of the square is: 100.0

# %% [markdown]
# BEGIN
# WRITE INPUT STATEMENT
# TAKE INPUT AS SIDE OF SQUARE
# CALCULATE AREA
# PRINT AREA
# END

# %%
#f string formating
name="deepak"
age=24
salary=35000.87876
print("The name is",name,"The age is",age)
print(f"The name is {name} and the age is {age}")
print(f"salary is:{salary:.2f}") #preission
# Out:
# The name is deepak The age is 24
# The name is deepak and the age is 24
# salary is:35000.88

# %%
#padding
num=45
print(f"{num:05d}")
# Out:
# 00045

# %%
#alignment 
text="python"
print(f"{text:<10}") #left alignment
print(f"{text:^10}") #center alignment
print(f"{text:>10}") # right alignment
# Out:
# python
#   python
#     python

# %%
#string basics
a='this is a string'
b="this is also a string"
c='''this is also another string'''

d="this is deepak's class"

# %%
#concatenation joining a string
a=5
b=6
c=a+b 
print(c)

a="mango"
b="apple"
d=a+b 
c=a+" "+b 
print(d)
print(c)
# Out:
# 11
# mangoapple
# mango apple

# %%
#lenght - len() - to find the leanth of the string and is a type of the function
print(len(a)) #mango- letter '5'
# Out:
# 5

# %%
print(25,25,27,sep=':') #seperator
print('hello','name',end='?') #ending each string
print('loading',end='..........')
print('done')
# Out:
# 25:25:27
# hello name?loading..........done

# %%
#escape  sequene tool
#\n moving to the next line
#\t moving 5 tab spaces forward the are more like 
print('hi this is my \nfirst class')
print('hi this is my \\first class')
# Out:
# hi this is my
# first class
# hi this is my \first class

# %%
# string indexing
name='deepak'
print(name[2])
# Out:
# e

# %%
new='this@ is a string'
print(new[4]) #positive indexing
print(new[-5]) #negative indexing
# Out:
# @
# t

# %%
#slicing strings
#string [start:stop:step]
apple='this is a new string'
print(apple[0:6])
print(apple[:])
print(apple[:7])
print(apple[::2]) #step skip 2 elements
print(apple[-5:-1])
# Out:
# this i
# this is a new string
# this is
# ti sanwsrn
# trin
